# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy as np
import matplotlib.pyplot as plt
import random
import glob

# %%
epochs = 1000
n_hidden = 128
OBSERVE_LENGTH = 10
PREDICT_LENGTH = 5
dim_input = 15
learning_rate = 0.0001
batch_size = 64

model_name = 'sslstm_epoch_{}_hidden_{}_observe_{}_predict_{}'.format(epochs, n_hidden, OBSERVE_LENGTH, PREDICT_LENGTH)

# %%
TRAIN_FOLDERS = '/home/dataset/training_observe_{}_predict_{}/*/'.format(OBSERVE_LENGTH, PREDICT_LENGTH)
TEST_FOLDERS = '/home/dataset/validation_observe_{}_predict_{}/*/'.format(OBSERVE_LENGTH, PREDICT_LENGTH)

train_folders = glob.glob(TRAIN_FOLDERS)
val_ratio = 0.1

print('train folder num:', len(train_folders))
# Out:
# train folder num: 20000

# %%
test_folders = glob.glob(TEST_FOLDERS)
test_num = len(test_folders)
print('test folder num:', len(test_folders))
# Out:
# test folder num: 4000

# %%
train_X = []
train_y = []
for folder in train_folders:
    file_x = folder + 'X.npy'
    train_X.append(np.load(file_x))
    
    file_y = folder + 'y.npy'
    train_y.append(np.load(file_y))
    
train_X = np.array(train_X)
train_y = np.array(train_y)

test_X = []
test_y = []
for folder in test_folders:
    file_x = folder + 'X.npy'
    test_X.append(np.load(file_x))
    
    file_y = folder + 'y.npy'
    test_y.append(np.load(file_y))
    
test_X = np.array(test_X)
test_y = np.array(test_y)


print("train X: ", train_X.shape)
print("train y: ", train_y.shape)

print("test X: ", test_X.shape)
print("test y: ", test_y.shape)
# Out:
# train X:  (20000, 10, 15)
# train y:  (20000, 5, 3)
# test X:  (4000, 10, 15)
# test y:  (4000, 5, 3)

# %%
def build_model():
    opt = optimizers.RMSprop(lr=learning_rate)
    model = tf.keras.Sequential()
    #lstm encoder
    model.add(layers.GRU(n_hidden,
                  input_shape=(OBSERVE_LENGTH, dim_input),
                  return_sequences=False,
                  stateful=False,
                  dropout=0.2))
    model.add(layers.RepeatVector(PREDICT_LENGTH))
    #lstm decoder
    model.add(layers.GRU(n_hidden,
                  return_sequences=True,
                  stateful=False,
                  dropout=0.2))
    model.add(layers.TimeDistributed(layers.Dense(3), input_shape=(PREDICT_LENGTH, None)))
    model.add(layers.Activation('linear'))
    model.compile(loss='mse', optimizer=opt)
    
    print(model.summary())
    return model

# %%
# Aggregated Training Error
model = build_model()

checkpointer = ModelCheckpoint(filepath="/home/zg2309/model/{}.h5".format(model_name), verbose=1, save_best_only=True)
history = model.fit(train_X, train_y, validation_split=val_ratio, batch_size=batch_size, epochs=epochs, verbose=1, callbacks=[checkpointer])
# Out:
# WARNING:tensorflow:From /home/zg2309/anaconda3/envs/waymo/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               55296
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 5, 128)            0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 5, 128)            98688
# _________________________________________________________________
# time_distributed (TimeDistri (None, 5, 3)              387
# _________________________________________________________________
# activation (Activation)      (None, 5, 3)              0
# =================================================================
# Total params: 154,371
# Trainable params: 154,371
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From /home/zg2309/anaconda3/envs/waymo/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.2283
# Epoch 00001: val_loss improved from inf to 0.17706, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 28s 2ms/sample - loss: 0.2282 - val_loss: 0.1771
# Epoch 2/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.1634
# Epoch 00002: val_loss improved from 0.17706 to 0.12377, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 18s 997us/sample - loss: 0.1634 - val_loss: 0.1238
# Epoch 3/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.1271
# Epoch 00003: val_loss improved from 0.12377 to 0.08626, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 18s 976us/sample - loss: 0.1271 - val_loss: 0.0863
# Epoch 4/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.1052
# Epoch 00004: val_loss improved from 0.08626 to 0.06643, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 18s 989us/sample - loss: 0.1053 - val_loss: 0.0664
# Epoch 5/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0922
# Epoch 00005: val_loss improved from 0.06643 to 0.05583, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 17s 917us/sample - loss: 0.0923 - val_loss: 0.0558
# Epoch 6/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0809
# Epoch 00006: val_loss improved from 0.05583 to 0.04828, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 17s 936us/sample - loss: 0.0809 - val_loss: 0.0483
# Epoch 7/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0762
# Epoch 00007: val_loss improved from 0.04828 to 0.04200, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 16s 886us/sample - loss: 0.0761 - val_loss: 0.0420
# Epoch 8/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0700
# Epoch 00008: val_loss improved from 0.04200 to 0.03577, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 16s 905us/sample - loss: 0.0700 - val_loss: 0.0358
# Epoch 9/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0661
# Epoch 00009: val_loss did not improve from 0.03577
# 18000/18000 [==============================] - 15s 807us/sample - loss: 0.0661 - val_loss: 0.0376
# Epoch 10/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0641
# Epoch 00010: val_loss improved from 0.03577 to 0.02953, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 15s 826us/sample - loss: 0.0641 - val_loss: 0.0295
# Epoch 11/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0607
# Epoch 00011: val_loss improved from 0.02953 to 0.02925, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 15s 836us/sample - loss: 0.0607 - val_loss: 0.0292
# Epoch 12/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0595
# Epoch 00012: val_loss did not improve from 0.02925
# 18000/18000 [==============================] - 15s 819us/sample - loss: 0.0595 - val_loss: 0.0298
# Epoch 13/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0579
# Epoch 00013: val_loss improved from 0.02925 to 0.02817, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 14s 789us/sample - loss: 0.0579 - val_loss: 0.0282
# Epoch 14/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0544
# Epoch 00014: val_loss improved from 0.02817 to 0.02472, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 15s 834us/sample - loss: 0.0544 - val_loss: 0.0247
# Epoch 15/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0531
# Epoch 00015: val_loss did not improve from 0.02472
# 18000/18000 [==============================] - 15s 829us/sample - loss: 0.0532 - val_loss: 0.0280
# Epoch 16/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0522
# Epoch 00016: val_loss did not improve from 0.02472
# 18000/18000 [==============================] - 13s 749us/sample - loss: 0.0522 - val_loss: 0.0258
# Epoch 17/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0490
# Epoch 00017: val_loss improved from 0.02472 to 0.02345, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 15s 859us/sample - loss: 0.0489 - val_loss: 0.0235
# Epoch 18/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0486
# Epoch 00018: val_loss improved from 0.02345 to 0.02119, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 16s 896us/sample - loss: 0.0488 - val_loss: 0.0212
# Epoch 19/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0474
# Epoch 00019: val_loss did not improve from 0.02119
# 18000/18000 [==============================] - 15s 807us/sample - loss: 0.0475 - val_loss: 0.0222
# Epoch 20/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0471
# Epoch 00020: val_loss did not improve from 0.02119
# 18000/18000 [==============================] - 16s 872us/sample - loss: 0.0470 - val_loss: 0.0214
# Epoch 21/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0459
# Epoch 00021: val_loss improved from 0.02119 to 0.02075, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 16s 892us/sample - loss: 0.0458 - val_loss: 0.0207
# Epoch 22/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0446
# Epoch 00022: val_loss did not improve from 0.02075
# 18000/18000 [==============================] - 15s 829us/sample - loss: 0.0445 - val_loss: 0.0209
# Epoch 23/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0429
# Epoch 00023: val_loss improved from 0.02075 to 0.01872, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 16s 901us/sample - loss: 0.0429 - val_loss: 0.0187
# Epoch 24/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0416
# Epoch 00024: val_loss did not improve from 0.01872
# 18000/18000 [==============================] - 15s 841us/sample - loss: 0.0416 - val_loss: 0.0203
# Epoch 25/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0400
# Epoch 00025: val_loss improved from 0.01872 to 0.01836, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 14s 771us/sample - loss: 0.0400 - val_loss: 0.0184
# Epoch 26/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0400
# Epoch 00026: val_loss did not improve from 0.01836
# 18000/18000 [==============================] - 16s 864us/sample - loss: 0.0400 - val_loss: 0.0187
# Epoch 27/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0387
# Epoch 00027: val_loss did not improve from 0.01836
# 18000/18000 [==============================] - 15s 849us/sample - loss: 0.0387 - val_loss: 0.0192
# Epoch 28/1000
# 17856/18000 [============================>.] - ETA: 0s - loss: 0.0383
# Epoch 00028: val_loss did not improve from 0.01836
# 18000/18000 [==============================] - 14s 788us/sample - loss: 0.0383 - val_loss: 0.0193
# Epoch 29/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0364
# Epoch 00029: val_loss improved from 0.01836 to 0.01711, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 15s 849us/sample - loss: 0.0364 - val_loss: 0.0171
# Epoch 30/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0356
# Epoch 00030: val_loss did not improve from 0.01711
# 18000/18000 [==============================] - 15s 856us/sample - loss: 0.0356 - val_loss: 0.0178
# Epoch 31/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0353
# Epoch 00031: val_loss improved from 0.01711 to 0.01560, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 14s 797us/sample - loss: 0.0353 - val_loss: 0.0156
# Epoch 32/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0341
# Epoch 00032: val_loss did not improve from 0.01560
# 18000/18000 [==============================] - 15s 845us/sample - loss: 0.0341 - val_loss: 0.0181
# Epoch 33/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0333
# Epoch 00033: val_loss did not improve from 0.01560
# 18000/18000 [==============================] - 15s 830us/sample - loss: 0.0333 - val_loss: 0.0214
# Epoch 34/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0327
# Epoch 00034: val_loss did not improve from 0.01560
# 18000/18000 [==============================] - 14s 789us/sample - loss: 0.0327 - val_loss: 0.0170
# Epoch 35/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0322
# Epoch 00035: val_loss did not improve from 0.01560
# 18000/18000 [==============================] - 15s 829us/sample - loss: 0.0322 - val_loss: 0.0158
# Epoch 36/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0329
# Epoch 00036: val_loss did not improve from 0.01560
# 18000/18000 [==============================] - 16s 871us/sample - loss: 0.0329 - val_loss: 0.0178
# Epoch 37/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0308
# Epoch 00037: val_loss improved from 0.01560 to 0.01468, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 14s 785us/sample - loss: 0.0308 - val_loss: 0.0147
# Epoch 38/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0307
# Epoch 00038: val_loss did not improve from 0.01468
# 18000/18000 [==============================] - 16s 884us/sample - loss: 0.0307 - val_loss: 0.0173
# Epoch 39/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0309
# Epoch 00039: val_loss did not improve from 0.01468
# 18000/18000 [==============================] - 15s 854us/sample - loss: 0.0309 - val_loss: 0.0155
# Epoch 40/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0301
# Epoch 00040: val_loss did not improve from 0.01468
# 18000/18000 [==============================] - 14s 786us/sample - loss: 0.0301 - val_loss: 0.0196
# Epoch 41/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0296
# Epoch 00041: val_loss did not improve from 0.01468
# 18000/18000 [==============================] - 15s 807us/sample - loss: 0.0296 - val_loss: 0.0150
# Epoch 42/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0292
# Epoch 00042: val_loss did not improve from 0.01468
# 18000/18000 [==============================] - 15s 826us/sample - loss: 0.0292 - val_loss: 0.0166
# Epoch 43/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0293
# Epoch 00043: val_loss improved from 0.01468 to 0.01394, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 14s 793us/sample - loss: 0.0292 - val_loss: 0.0139
# Epoch 44/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0275
# Epoch 00044: val_loss did not improve from 0.01394
# 18000/18000 [==============================] - 15s 817us/sample - loss: 0.0276 - val_loss: 0.0192
# Epoch 45/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0282
# Epoch 00045: val_loss did not improve from 0.01394
# 18000/18000 [==============================] - 15s 839us/sample - loss: 0.0282 - val_loss: 0.0166
# Epoch 46/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0275
# Epoch 00046: val_loss did not improve from 0.01394
# 18000/18000 [==============================] - 14s 802us/sample - loss: 0.0275 - val_loss: 0.0156
# Epoch 47/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0279
# Epoch 00047: val_loss did not improve from 0.01394
# 18000/18000 [==============================] - 16s 885us/sample - loss: 0.0279 - val_loss: 0.0143
# Epoch 48/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0275
# Epoch 00048: val_loss did not improve from 0.01394
# 18000/18000 [==============================] - 15s 831us/sample - loss: 0.0274 - val_loss: 0.0159
# Epoch 49/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0276
# Epoch 00049: val_loss improved from 0.01394 to 0.01334, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 14s 801us/sample - loss: 0.0276 - val_loss: 0.0133
# Epoch 50/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0270
# Epoch 00050: val_loss did not improve from 0.01334
# 18000/18000 [==============================] - 15s 809us/sample - loss: 0.0270 - val_loss: 0.0134
# Epoch 51/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0275
# Epoch 00051: val_loss did not improve from 0.01334
# 18000/18000 [==============================] - 15s 847us/sample - loss: 0.0275 - val_loss: 0.0154
# Epoch 52/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0273
# Epoch 00052: val_loss did not improve from 0.01334
# 18000/18000 [==============================] - 15s 819us/sample - loss: 0.0274 - val_loss: 0.0159
# Epoch 53/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0267
# Epoch 00053: val_loss did not improve from 0.01334
# 18000/18000 [==============================] - 14s 798us/sample - loss: 0.0267 - val_loss: 0.0138
# Epoch 54/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0266
# Epoch 00054: val_loss did not improve from 0.01334
# 18000/18000 [==============================] - 16s 863us/sample - loss: 0.0266 - val_loss: 0.0141
# Epoch 55/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0251
# Epoch 00055: val_loss did not improve from 0.01334
# 18000/18000 [==============================] - 15s 817us/sample - loss: 0.0252 - val_loss: 0.0194
# Epoch 56/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0261
# Epoch 00056: val_loss did not improve from 0.01334
# 18000/18000 [==============================] - 14s 786us/sample - loss: 0.0261 - val_loss: 0.0158
# Epoch 57/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0260
# Epoch 00057: val_loss improved from 0.01334 to 0.01317, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 15s 858us/sample - loss: 0.0260 - val_loss: 0.0132
# Epoch 58/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0260
# Epoch 00058: val_loss did not improve from 0.01317
# 18000/18000 [==============================] - 15s 828us/sample - loss: 0.0260 - val_loss: 0.0137
# Epoch 59/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0255
# Epoch 00059: val_loss did not improve from 0.01317
# 18000/18000 [==============================] - 14s 795us/sample - loss: 0.0255 - val_loss: 0.0139
# Epoch 60/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0254
# Epoch 00060: val_loss did not improve from 0.01317
# 18000/18000 [==============================] - 16s 868us/sample - loss: 0.0254 - val_loss: 0.0150
# Epoch 61/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0244
# Epoch 00061: val_loss improved from 0.01317 to 0.01218, saving model to /home/zg2309/model/sslstm_epoch_1000_hidden_128_observe_10_predict_5.h5
# 18000/18000 [==============================] - 16s 916us/sample - loss: 0.0244 - val_loss: 0.0122
# Epoch 62/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0249
# Epoch 00062: val_loss did not improve from 0.01218
# 18000/18000 [==============================] - 14s 801us/sample - loss: 0.0249 - val_loss: 0.0133
# Epoch 63/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0241
# Epoch 00063: val_loss did not improve from 0.01218
# 18000/18000 [==============================] - 17s 917us/sample - loss: 0.0241 - val_loss: 0.0150
# Epoch 64/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0245
# Epoch 00064: val_loss did not improve from 0.01218
# 18000/18000 [==============================] - 16s 895us/sample - loss: 0.0245 - val_loss: 0.0136
# Epoch 65/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0233
# Epoch 00065: val_loss did not improve from 0.01218
# 18000/18000 [==============================] - 15s 828us/sample - loss: 0.0233 - val_loss: 0.0136
# Epoch 66/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0236- ETA:
# Epoch 00066: val_loss did not improve from 0.01218
# 18000/18000 [==============================] - 16s 887us/sample - loss: 0.0236 - val_loss: 0.0139
# Epoch 67/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0234
# Epoch 00067: val_loss did not improve from 0.01218
# 18000/18000 [==============================] - 16s 915us/sample - loss: 0.0234 - val_loss: 0.0168
# Epoch 68/1000
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0232
# Epoch 00068: val_loss did not improve from 0.01218
# 18000/18000 [==============================] - 15s 861us/sample - loss: 0.0231 - val_loss: 0.0123
# Epoch 69/1000
# 17984/18000 [============================>.] - ETA: 0s - loss: 0.0230
# Epoch 00069: val_loss did not improve from 0.01218
# 18000/18000 [==============================] - 16s 884us/sample - loss: 0.0230 - val_loss: 0.0125
# Epoch 70/1000
#  5952/18000 [========>.....................] - ETA: 10s - loss: 0.0227

# %%
# Plot training & validation loss values
fig = plt.gcf()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
fig.savefig('/home/zg2309/history/{}'.format(model_name))
plt.close(fig)

score = model.evaluate(test_X, test_y, batch_size=batch_size)
